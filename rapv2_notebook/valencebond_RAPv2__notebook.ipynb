# %%
# !git clone https://github.com/valencebond/Strong_Baseline_of_Pedestrian_Attribute_Recognition.git
# Out:
# Cloning into 'Strong_Baseline_of_Pedestrian_Attribute_Recognition'...
# remote: Enumerating objects: 103, done.
# remote: Total 103 (delta 0), reused 0 (delta 0), pack-reused 103
# Receiving objects: 100% (103/103), 2.81 MiB | 15.20 MiB/s, done.
# Resolving deltas: 100% (42/42), done.

# %%
# cd pedestrian-attribute-recognition-pytorch/dataset/rap2/
# Out:
# /content/pedestrian-attribute-recognition-pytorch/dataset/pa100k

# %%
mkdir data

# %%
mkdir data/RAP2

# %%
cd data/RAP2
# Out:
# /content/data/RAP2

# %%
# from google.colab import drive
# drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1j21odWyJUb2qQRNirUo7ykva6c2YcRmd' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1j21odWyJUb2qQRNirUo7ykva6c2YcRmd" -O RAP_dataset.zip && rm -rf /tmp/cookies.tx
# Out:
# --2020-07-14 07:19:54--  https://docs.google.com/uc?export=download&confirm=PjUX&id=1j21odWyJUb2qQRNirUo7ykva6c2YcRmd
# Resolving docs.google.com (docs.google.com)... 209.85.234.100, 209.85.234.102, 209.85.234.101, ...
# Connecting to docs.google.com (docs.google.com)|209.85.234.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-2o-docs.googleusercontent.com/docs/securesc/37c3l6pong96hs6h5dbgojl9ml6sme2a/vlgpp2lbn0086koe5okap1le1ga988lo/1594711125000/14548190299809122583/15517388912570734804Z/1j21odWyJUb2qQRNirUo7ykva6c2YcRmd?e=download [following]
# --2020-07-14 07:19:54--  https://doc-0g-2o-docs.googleusercontent.com/docs/securesc/37c3l6pong96hs6h5dbgojl9ml6sme2a/vlgpp2lbn0086koe5okap1le1ga988lo/1594711125000/14548190299809122583/15517388912570734804Z/1j21odWyJUb2qQRNirUo7ykva6c2YcRmd?e=download
# Resolving doc-0g-2o-docs.googleusercontent.com (doc-0g-2o-docs.googleusercontent.com)... 172.217.214.132, 2607:f8b0:4001:c05::84
# Connecting to doc-0g-2o-docs.googleusercontent.com (doc-0g-2o-docs.googleusercontent.com)|172.217.214.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=nsjr7h6dobq3c&continue=https://doc-0g-2o-docs.googleusercontent.com/docs/securesc/37c3l6pong96hs6h5dbgojl9ml6sme2a/vlgpp2lbn0086koe5okap1le1ga988lo/1594711125000/14548190299809122583/15517388912570734804Z/1j21odWyJUb2qQRNirUo7ykva6c2YcRmd?e%3Ddownload&hash=vvn0444tcousjv7baglq1cpuaidr9k21 [following]
# --2020-07-14 07:19:54--  https://docs.google.com/nonceSigner?nonce=nsjr7h6dobq3c&continue=https://doc-0g-2o-docs.googleusercontent.com/docs/securesc/37c3l6pong96hs6h5dbgojl9ml6sme2a/vlgpp2lbn0086koe5okap1le1ga988lo/1594711125000/14548190299809122583/15517388912570734804Z/1j21odWyJUb2qQRNirUo7ykva6c2YcRmd?e%3Ddownload&hash=vvn0444tcousjv7baglq1cpuaidr9k21
# Connecting to docs.google.com (docs.google.com)|209.85.234.100|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-0g-2o-docs.googleusercontent.com/docs/securesc/37c3l6pong96hs6h5dbgojl9ml6sme2a/vlgpp2lbn0086koe5okap1le1ga988lo/1594711125000/14548190299809122583/15517388912570734804Z/1j21odWyJUb2qQRNirUo7ykva6c2YcRmd?e=download&nonce=nsjr7h6dobq3c&user=15517388912570734804Z&hash=p3n3uav17fof3ifjv97b5s60voktikpd [following]
# --2020-07-14 07:19:54--  https://doc-0g-2o-docs.googleusercontent.com/docs/securesc/37c3l6pong96hs6h5dbgojl9ml6sme2a/vlgpp2lbn0086koe5okap1le1ga988lo/1594711125000/14548190299809122583/15517388912570734804Z/1j21odWyJUb2qQRNirUo7ykva6c2YcRmd?e=download&nonce=nsjr7h6dobq3c&user=15517388912570734804Z&hash=p3n3uav17fof3ifjv97b5s60voktikpd
# Connecting to doc-0g-2o-docs.googleusercontent.com (doc-0g-2o-docs.googleusercontent.com)|172.217.214.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-zip-compressed]
# Saving to: ‘RAP_dataset.zip’
#
# RAP_dataset.zip         [         <=>        ]   3.93G  52.1MB/s    in 74s
#
# 2020-07-14 07:21:08 (54.6 MB/s) - ‘RAP_dataset.zip’ saved [4217275352]

# %%
# Out:
# RAP_dataset.zip

# %%
cd data/RAP2
# Out:
# [Errno 2] No such file or directory: 'data/RAP2'
# /content/data/RAP2

# %%
# !unzip -P casia_crise_195610 RAP_dataset.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: RAP_dataset/CAM22-2014-04-17-20140417130943-20140417131531-tarid141-frame1087-line2.png
#   inflating: RAP_dataset/CAM12-2014-03-28-20140328151234-20140328152425-tarid744-frame3872-line1.png
#   inflating: RAP_dataset/CAM19-2014-03-02-20140302140136-20140302140726-tarid105-frame1673-line1.png
#   inflating: RAP_dataset/CAM22-2014-03-28-20140328154615-20140328155155-tarid392-frame3192-line2.png
#   inflating: RAP_dataset/CAM14-2014-04-23-20140423160834-20140423162026-tarid276-frame3460-line1.png
#   inflating: RAP_dataset/CAM27-2014-03-27-20140327103530-20140327104230-tarid124-frame3154-line1.png
#   inflating: RAP_dataset/CAM01-2014-03-12-20140312172934-20140312174426-tarid51-frame2107-line1.png
#   inflating: RAP_dataset/CAM25-2014-02-17-20140217104440-20140217105028-tarid378-frame2944-line2.png
#  extracting: RAP_dataset/CAM12-2014-03-03-20140303133323-20140303133915-tarid446-frame2267-line1.png
#   inflating: RAP_dataset/CAM30-2014-04-19-20140419113255-20140419113758-tarid23-frame379-line2.png
#   inflating: RAP_dataset/CAM12-2014-04-17-20140417133130-20140417133722-tarid329-frame1577-line1.png
#   inflating: RAP_dataset/CAM28-2014-03-02-20140302142819-20140302144127-tarid136-frame4004-line1.png
#   inflating: RAP_dataset/CAM01-2014-02-26-20140226111837-20140226112425-tarid3-frame1614-line1.png
#   inflating: RAP_dataset/CAM22-2014-02-26-20140226113033-20140226113621-tarid135-frame1176-line2.png
#   inflating: RAP_dataset/CAM17-2013-12-23-20131223125238-20131223125826-tarid81-frame1868-line2.png
#   inflating: RAP_dataset/CAM13-2014-04-19-20140419114705-20140419115301-tarid34-frame1140-line1.png
#   inflating: RAP_dataset/CAM14-2014-03-10-20140310131827-20140310132415-tarid86-frame1522-line1.png
#   inflating: RAP_dataset/CAM21-2014-04-17-20140417131157-20140417132145-tarid297-frame3348-line1.png
#   inflating: RAP_dataset/CAM17-2014-02-15-20140215162652-20140215163156-tarid185-frame1881-line1.png
#   inflating: RAP_dataset/CAM14-2014-02-25-20140225154615-20140225155727-tarid302-frame5864-line1.png
#  extracting: RAP_dataset/CAM12-2014-02-22-20140222102635-20140222103223-tarid1132-frame4306-line1.png
#   inflating: RAP_dataset/CAM10-2014-03-28-20140328155302-20140328155858-tarid363-frame3987-line1.png
#   inflating: RAP_dataset/CAM17-2014-03
#   inflating: RAP_dataset/CAM22-2014-02-17-20140217103857-20140217104445-tarid224-frame4036-line2.png
#   inflating: RAP_dataset/CAM18-2014-03-26-20140326143908-20140326144456-tarid83-frame1783-line1.png
#   inflating: RAP_dataset/CAM18-2014-03-20-20140320163556-20140320164144-tarid365-frame3626-line1.png
#   inflating: RAP_dataset/CAM22-2014-04-22-20140422124557-20140422125317-tarid173-frame1994-line2.png

# %%
# !rm RAP_dataset.zip

# %%
# !pip install torch==1.4.0
# Out:
# Requirement already satisfied: torch==1.4.0 in /usr/local/lib/python2.7/dist-packages (1.4.0)

# %%
# !pip install torchvision==0.5.0
# Out:
# Requirement already satisfied: torchvision==0.5.0 in /usr/local/lib/python2.7/dist-packages (0.5.0)
# Requirement already satisfied: six in /usr/local/lib/python2.7/dist-packages (from torchvision==0.5.0) (1.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python2.7/dist-packages (from torchvision==0.5.0) (1.16.4)
# Requirement already satisfied: torch==1.4.0 in /usr/local/lib/python2.7/dist-packages (from torchvision==0.5.0) (1.4.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python2.7/dist-packages (from torchvision==0.5.0) (4.3.0)
# Requirement already satisfied: olefile in /usr/local/lib/python2.7/dist-packages (from pillow>=4.1.1->torchvision==0.5.0) (0.46)

# %%
# !pip install tqdm==4.43.0
# Out:
# Collecting tqdm==4.43.0
#   Downloading https://files.pythonhosted.org/packages/47/55/fd9170ba08a1a64a18a7f8a18f088037316f2a41be04d2fe6ece5a653e8f/tqdm-4.43.0-py2.py3-none-any.whl (59kB)
#      |████████████████████████████████| 61kB 1.8MB/s
# ERROR: fastai 0.7.0 has requirement torch<0.4, but you'll have torch 1.4.0 which is incompatible.
# Installing collected packages: tqdm
#   Found existing installation: tqdm 4.28.1
#     Uninstalling tqdm-4.28.1:
#       Successfully uninstalled tqdm-4.28.1
# Successfully installed tqdm-4.43.0

# %%
# !pip install easydict==1.9
# Out:
# Requirement already satisfied: easydict==1.9 in /usr/local/lib/python2.7/dist-packages (1.9)

# %%
# !mv data Strong_Baseline_of_Pedestrian_Attribute_Recognition/

# %%
# !ls Strong_Baseline_of_Pedestrian_Attribute_Recognition/
# Out:
# batch_engine.py  data	  imgs	metrics  README.md	   tools     train.sh
# config.py	 dataset  loss	models	 requirements.txt  train.py

# %%
# !ls
# Out:
# RAP_dataset

# %%
cd RAP2/
# Out:
# /content/Strong_Baseline_of_Pedestrian_Attribute_Recognition/data/RAP2

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1R__yKSN_7ZhVU4nvj7NdJzUv1qe3ns4v' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1R__yKSN_7ZhVU4nvj7NdJzUv1qe3ns4v" -O RAP_annotation.zip && rm -rf /tmp/cookies.tx
# Out:
# --2020-07-14 07:36:07--  https://docs.google.com/uc?export=download&confirm=&id=1R__yKSN_7ZhVU4nvj7NdJzUv1qe3ns4v
# Resolving docs.google.com (docs.google.com)... 209.85.234.138, 209.85.234.139, 209.85.234.101, ...
# Connecting to docs.google.com (docs.google.com)|209.85.234.138|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-04-bc-docs.googleusercontent.com/docs/securesc/2t71efp5p0qa2f0fvk8l1uoarks7v59f/4fesp7481nfko8tq9g1trduoepnildkv/1594712100000/14548190299809122583/10451493219532259952Z/1R__yKSN_7ZhVU4nvj7NdJzUv1qe3ns4v?e=download [following]
# --2020-07-14 07:36:08--  https://doc-04-bc-docs.googleusercontent.com/docs/securesc/2t71efp5p0qa2f0fvk8l1uoarks7v59f/4fesp7481nfko8tq9g1trduoepnildkv/1594712100000/14548190299809122583/10451493219532259952Z/1R__yKSN_7ZhVU4nvj7NdJzUv1qe3ns4v?e=download
# Resolving doc-04-bc-docs.googleusercontent.com (doc-04-bc-docs.googleusercontent.com)... 172.217.214.132, 2607:f8b0:4001:c05::84
# Connecting to doc-04-bc-docs.googleusercontent.com (doc-04-bc-docs.googleusercontent.com)|172.217.214.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=1ui89jm8obnh2&continue=https://doc-04-bc-docs.googleusercontent.com/docs/securesc/2t71efp5p0qa2f0fvk8l1uoarks7v59f/4fesp7481nfko8tq9g1trduoepnildkv/1594712100000/14548190299809122583/10451493219532259952Z/1R__yKSN_7ZhVU4nvj7NdJzUv1qe3ns4v?e%3Ddownload&hash=g5b4vp97qo7djc65jlsop18sg2laav9r [following]
# --2020-07-14 07:36:08--  https://docs.google.com/nonceSigner?nonce=1ui89jm8obnh2&continue=https://doc-04-bc-docs.googleusercontent.com/docs/securesc/2t71efp5p0qa2f0fvk8l1uoarks7v59f/4fesp7481nfko8tq9g1trduoepnildkv/1594712100000/14548190299809122583/10451493219532259952Z/1R__yKSN_7ZhVU4nvj7NdJzUv1qe3ns4v?e%3Ddownload&hash=g5b4vp97qo7djc65jlsop18sg2laav9r
# Connecting to docs.google.com (docs.google.com)|209.85.234.138|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-04-bc-docs.googleusercontent.com/docs/securesc/2t71efp5p0qa2f0fvk8l1uoarks7v59f/4fesp7481nfko8tq9g1trduoepnildkv/1594712100000/14548190299809122583/10451493219532259952Z/1R__yKSN_7ZhVU4nvj7NdJzUv1qe3ns4v?e=download&nonce=1ui89jm8obnh2&user=10451493219532259952Z&hash=ft76d6g35u4c06ge37c21fhtte2nqmaj [following]
# --2020-07-14 07:36:08--  https://doc-04-bc-docs.googleusercontent.com/docs/securesc/2t71efp5p0qa2f0fvk8l1uoarks7v59f/4fesp7481nfko8tq9g1trduoepnildkv/1594712100000/14548190299809122583/10451493219532259952Z/1R__yKSN_7ZhVU4nvj7NdJzUv1qe3ns4v?e=download&nonce=1ui89jm8obnh2&user=10451493219532259952Z&hash=ft76d6g35u4c06ge37c21fhtte2nqmaj
# Connecting to doc-04-bc-docs.googleusercontent.com (doc-04-bc-docs.googleusercontent.com)|172.217.214.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/x-zip-compressed]
# Saving to: ‘RAP_annotation.zip’
#
# RAP_annotation.zip      [ <=>                ]   5.58M  --.-KB/s    in 0.03s
#
# 2020-07-14 07:36:08 (162 MB/s) - ‘RAP_annotation.zip’ saved [5846663]

# %%
# !unzip -P casia_crise_195610 RAP_annotation.zip
# Out:
# Archive:  RAP_annotation.zip
#    creating: RAP_annotation/
#  extracting: RAP_annotation/.gitsave
#   inflating: RAP_annotation/ReadMe
#   inflating: RAP_annotation/RAP_annotation.mat

# %%
cd ../..
# Out:
# /content/Strong_Baseline_of_Pedestrian_Attribute_Recognition

# %%
# !ls data/RAP2/
# Out:
# dataset.pkl  RAP_annotation  RAP_annotation.zip  RAP_dataset

# %%
# !python ./dataset/preprocess/format_rap2.py

# %%
cd Strong_Baseline_of_Pedestrian_Attribute_Recognition
# Out:
# /content/Strong_Baseline_of_Pedestrian_Attribute_Recognition

# %%
print()
# Out:
# hi

# %%
# %%writefile dataset/AttrDataset.py

import os
import pickle

import numpy as np
import torch.utils.data as data
from PIL import Image

from tools.function import get_pkl_rootpath
import torchvision.transforms as T
import codecs

class AttrDataset(data.Dataset):

    def __init__(self, split, args, transform=None, target_transform=None):

        assert args.dataset in ['PETA', 'PETA_dataset', 'PA100k', 'RAP', 'RAP2'], \
            f'dataset name {args.dataset} is not exist'

        data_path = get_pkl_rootpath(args.dataset)
        print(data_path)

        dataset_info = pickle.load(open(data_path, 'rb+'), encoding="latin1")

        img_id = dataset_info.image_name
        attr_label = dataset_info.label

        assert split in dataset_info.partition.keys(), f'split {split} is not exist'

        self.dataset = args.dataset
        self.transform = transform
        self.target_transform = target_transform

        self.root_path = dataset_info.root

        self.attr_id = dataset_info.attr_name
        self.attr_num = len(self.attr_id)

        self.img_idx = dataset_info.partition[split]

        if isinstance(self.img_idx, list):
            self.img_idx = self.img_idx[0]  # default partition 0
        self.img_num = self.img_idx.shape[0]
        self.img_id = [img_id[i] for i in self.img_idx]
        self.label = attr_label[self.img_idx]

    def __getitem__(self, index):

        imgname, gt_label, imgidx = self.img_id[index], self.label[index], self.img_idx[index]
        imgpath = os.path.join(self.root_path, imgname)
        img = Image.open(imgpath)

        if self.transform is not None:
            img = self.transform(img)

        gt_label = gt_label.astype(np.float32)

        if self.target_transform is not None:
            gt_label = self.transform(gt_label)

        return img, gt_label, imgname

    def __len__(self):
        return len(self.img_id)


def get_transform(args):
    height = args.height
    width = args.width
    normalize = T.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    train_transform = T.Compose([
        T.Resize((height, width)),
        T.Pad(10),
        T.RandomCrop((height, width)),
        T.RandomHorizontalFlip(),
        T.ToTensor(),
        normalize,
    ])

    valid_transform = T.Compose([
        T.Resize((height, width)),
        T.ToTensor(),
        normalize
    ])

    return train_transform, valid_transform
# Out:
# Overwriting dataset/AttrDataset.py

# %%
# %%writefile train.py

import os
import pprint
from collections import OrderedDict, defaultdict

import numpy as np
import torch
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.utils.data import DataLoader

from batch_engine import valid_trainer, batch_trainer
from config import argument_parser
from dataset.AttrDataset import AttrDataset, get_transform
from loss.CE_loss import CEL_Sigmoid
from models.base_block import FeatClassifier, BaseClassifier
from models.resnet import resnet50
from tools.function import get_model_log_path, get_pedestrian_metrics
from tools.utils import time_str, save_ckpt, ReDirectSTD, set_seed

set_seed(605)


def main(args):
    visenv_name = args.dataset
    exp_dir = os.path.join('exp_result', args.dataset)
    model_dir, log_dir = get_model_log_path(exp_dir, visenv_name)
    stdout_file = os.path.join(log_dir, f'stdout_{time_str()}.txt')
    save_model_path = os.path.join(model_dir, 'ckpt_max.pth')

    if args.redirector:
        print('redirector stdout')
        ReDirectSTD(stdout_file, 'stdout', False)

    pprint.pprint(OrderedDict(args.__dict__))

    print('-' * 60)
    print(f'use GPU{args.device} for training')
    print(f'train set: {args.dataset} {args.train_split}, test set: {args.valid_split}')

    train_tsfm, valid_tsfm = get_transform(args)
    print(train_tsfm)

    train_set = AttrDataset(args=args, split=args.train_split, transform=train_tsfm)

    train_loader = DataLoader(
        dataset=train_set,
        batch_size=args.batchsize,
        shuffle=True,
        num_workers=4,
        pin_memory=True,
    )
    valid_set = AttrDataset(args=args, split=args.valid_split, transform=valid_tsfm)

    valid_loader = DataLoader(
        dataset=valid_set,
        batch_size=args.batchsize,
        shuffle=False,
        num_workers=4,
        pin_memory=True,
    )

    print(f'{args.train_split} set: {len(train_loader.dataset)}, '
          f'{args.valid_split} set: {len(valid_loader.dataset)}, '
          f'attr_num : {train_set.attr_num}')

    labels = train_set.label
    sample_weight = labels.mean(0)

    backbone = resnet50()
    classifier = BaseClassifier(nattr=train_set.attr_num)
    model = FeatClassifier(backbone, classifier)

    if torch.cuda.is_available():
        model = torch.nn.DataParallel(model).cuda()

    criterion = CEL_Sigmoid(sample_weight)

    param_groups = [{'params': model.module.finetune_params(), 'lr': args.lr_ft},
                    {'params': model.module.fresh_params(), 'lr': args.lr_new}]
    optimizer = torch.optim.SGD(param_groups, momentum=args.momentum, weight_decay=args.weight_decay, nesterov=False)
    lr_scheduler = ReduceLROnPlateau(optimizer, factor=0.1, patience=4)

    best_metric, epoch = trainer(epoch=args.train_epoch,
                                 model=model,
                                 train_loader=train_loader,
                                 valid_loader=valid_loader,
                                 criterion=criterion,
                                 optimizer=optimizer,
                                 lr_scheduler=lr_scheduler,
                                 path=save_model_path)

    print(f'{visenv_name},  best_metrc : {best_metric} in epoch{epoch}')


def trainer(epoch, model, train_loader, valid_loader, criterion, optimizer, lr_scheduler,
            path):
    maximum = float(-np.inf)
    best_epoch = 0

    result_list = defaultdict()

    for i in range(epoch):

        train_loss, train_gt, train_probs = batch_trainer(
            epoch=i,
            model=model,
            train_loader=train_loader,
            criterion=criterion,
            optimizer=optimizer,
        )

        valid_loss, valid_gt, valid_probs = valid_trainer(
            model=model,
            valid_loader=valid_loader,
            criterion=criterion,
        )

        lr_scheduler.step(metrics=valid_loss, epoch=i)

        train_result = get_pedestrian_metrics(train_gt, train_probs)
        valid_result = get_pedestrian_metrics(valid_gt, valid_probs)

        print(f'Evaluation on test set, \n',
              'ma: {:.4f},  pos_recall: {:.4f} , neg_recall: {:.4f} \n'.format(
                  valid_result.ma, np.mean(valid_result.label_pos_recall), np.mean(valid_result.label_neg_recall)),
              'Acc: {:.4f}, Prec: {:.4f}, Rec: {:.4f}, F1: {:.4f}'.format(
                  valid_result.instance_acc, valid_result.instance_prec, valid_result.instance_recall,
                  valid_result.instance_f1))

        print(f'{time_str()}')
        print('-' * 60)

        cur_metric = valid_result.ma

        if cur_metric > maximum:
            maximum = cur_metric
            best_epoch = i
            save_ckpt(model, path, i, maximum)

        result_list[i] = [train_result, valid_result]

    torch.save(result_list, os.path.join(os.path.dirname(path), 'metric_log.pkl'))

    return maximum, best_epoch


if __name__ == '__main__':
    parser = argument_parser()
    args = parser.parse_args()
    # args.batchsize = 
    args.train_epoch = 5
    main(args)

    # os.path.abspath()

"""

from tools.function import LogVisual
sys.modules['LogVisual'] = LogVisual
log = torch.load('./save/2018-10-29_21:17:34trlog')
"""
# Out:
# Overwriting train.py

# %%
# !CUDA_VISIBLE_DEVICES=0 python train.py RAP2
# Out:
# redirector stdout
# OrderedDict([('dataset', 'RAP2'),
#              ('debug', True),
#              ('batchsize', 64),
#              ('train_epoch', 5),
#              ('height', 256),
#              ('width', 192),
#              ('lr_ft', 0.01),
#              ('lr_new', 0.1),
#              ('classifier', 'base'),
#              ('momentum', 0.9),
#              ('weight_decay', 0.0005),
#              ('train_split', 'trainval'),
#              ('valid_split', 'test'),
#              ('device', 0),
#              ('redirector', True),
#              ('use_bn', True)])
# ------------------------------------------------------------
# use GPU0 for training
# train set: RAP2 trainval, test set: test
# Compose(
#     Resize(size=(256, 192), interpolation=PIL.Image.BILINEAR)
#     Pad(padding=10, fill=0, padding_mode=constant)
#     RandomCrop(size=(256, 192), padding=None)
#     RandomHorizontalFlip(p=0.5)
#     ToTensor()
#     Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
# )
# ./data/RAP2/dataset.pkl
# ./data/RAP2/dataset.pkl
# trainval set: 67943, test set: 16985, attr_num : 54
# 2020-07-14_08:30:21, Step 19/1062 in Ep 0, 1.29s  train_loss:30.4462
# 2020-07-14_08:30:47, Step 39/1062 in Ep 0, 1.30s  train_loss:22.5312
# 2020-07-14_08:31:13, Step 59/1062 in Ep 0, 1.30s  train_loss:21.8975
# 2020-07-14_08:31:39, Step 79/1062 in Ep 0, 1.29s  train_loss:21.3018
# 2020-07-14_08:32:05, Step 99/1062 in Ep 0, 1.30s  train_loss:20.1440
# 2020-07-14_08:32:31, Step 119/1062 in Ep 0, 1.31s  train_loss:21.0144
# 2020-07-14_08:32:57, Step 139/1062 in Ep 0, 1.31s  train_loss:20.7679
# 2020-07-14_08:33:23, Step 159/1062 in Ep 0, 1.31s  train_loss:21.6201
# 2020-07-14_08:33:49, Step 179/1062 in Ep 0, 1.31s  train_loss:19.8952
# 2020-07-14_08:34:15, Step 199/1062 in Ep 0, 1.30s  train_loss:19.7401
# 2020-07-14_08:34:41, Step 219/1062 in Ep 0, 1.29s  train_loss:22.2828
# 2020-07-14_08:35:07, Step 239/1062 in Ep 0, 1.31s  train_loss:18.3689
# 2020-07-14_08:35:33, Step 259/1062 in Ep 0, 1.30s  train_loss:19.2630
# 2020-07-14_08:35:59, Step 279/1062 in Ep 0, 1.30s  train_loss:19.8229
# 2020-07-14_08:36:25, Step 299/1062 in Ep 0, 1.29s  train_loss:21.0956
# 2020-07-14_08:36:51, Step 319/1062 in Ep 0, 1.29s  train_loss:18.9685
# 2020-07-14_08:37:17, Step 339/1062 in Ep 0, 1.29s  train_loss:19.1699
# 2020-07-14_08:37:43, Step 359/1062 in Ep 0, 1.30s  train_loss:18.7195
# 2020-07-14_08:38:08, Step 379/1062 in Ep 0, 1.30s  train_loss:20.7188
# 2020-07-14_08:38:35, Step 399/1062 in Ep 0, 1.31s  train_loss:19.0743
# 2020-07-14_08:39:01, Step 419/1062 in Ep 0, 1.31s  train_loss:17.4680
# 2020-07-14_08:39:27, Step 439/1062 in Ep 0, 1.30s  train_loss:19.1113
# 2020-07-14_08:39:53, Step 459/1062 in Ep 0, 1.31s  train_loss:19.0610
# 2020-07-14_08:40:19, Step 479/1062 in Ep 0, 1.29s  train_loss:18.6130
UserWarning: The epoch parameter in `scheduler.step()` was not necessary and is being deprecated where possible. Please use `scheduler.step()` to step the scheduler. During the deprecation, if epoch is different from None, the closed form is used instead of the new chainable form, where available. Please open an issue if you are unable to replicate your use case: https://github.com/pytorch/pytorch/issues/new/choose.
#   warnings.warn(EPOCH_DEPRECATION_WARNING, UserWarning)
# Evaluation on test set,
#  ma: 0.7009,  pos_recall: 0.4827 , neg_recall: 0.9192
#  Acc: 0.5923, Prec: 0.7433, Rec: 0.7281, F1: 0.7294
# 2020-07-14_08:54:47
# ------------------------------------------------------------
# 2020-07-14_08:55:15, Step 19/1062 in Ep 1, 1.30s  train_loss:16.9683
# 2020-07-14_08:55:41, Step 39/1062 in Ep 1, 1.29s  train_loss:16.7371
# 2020-07-14_08:56:07, Step 59/1062 in Ep 1, 1.29s  train_loss:17.9788
# 2020-07-14_08:56:34, Step 79/1062 in Ep 1, 1.36s  train_loss:16.7565
# 2020-07-14_08:57:00, Step 99/1062 in Ep 1, 1.29s  train_loss:17.3166
# 2020-07-14_08:57:26, Step 119/1062 in Ep 1, 1.29s  train_loss:17.1551
# 2020-07-14_08:57:52, Step 139/1062 in Ep 1, 1.29s  train_loss:17.9054
# 2020-07-14_08:58:18, Step 159/1062 in Ep 1, 1.30s  train_loss:16.7299
# 2020-07-14_08:58:44, Step 179/1062 in Ep 1, 1.30s  train_loss:18.1735
# 2020-07-14_08:59:10, Step 199/1062 in Ep 1, 1.31s  train_loss:15.8578
# 2020-07-14_08:59:36, Step 219/1062 in Ep 1, 1.30s  train_loss:17.0956
# 2020-07-14_09:00:02, Step 239/1062 in Ep 1, 1.30s  train_loss:18.4982
# 2020-07-14_09:00:28, Step 259/1062 in Ep 1, 1.29s  train_loss:17.4284
# 2020-07-14_09:00:54, Step 279/1062 in Ep 1, 1.30s  train_loss:17.3791
# 2020-07-14_09:01:20, Step 299/1062 in Ep 1, 1.28s  train_loss:18.6575
# 2020-07-14_09:01:46, Step 319/1062 in Ep 1, 1.30s  train_loss:16.4918
# 2020-07-14_09:02:12, Step 339/1062 in Ep 1, 1.30s  train_loss:18.7309
# 2020-07-14_09:02:38, Step 359/1062 in Ep 1, 1.31s  train_loss:16.2376
# 2020-07-14_09:03:04, Step 379/1062 in Ep 1, 1.31s  train_loss:18.1938
# 2020-07-14_09:03:30, Step 399/1062 in Ep 1, 1.29s  train_loss:18.0483
# 2020-07-14_09:03:56, Step 419/1062 in Ep 1, 1.29s  train_loss:17.0593
# 2020-07-14_09:04:21, Step 439/1062 in Ep 1, 1.29s  train_loss:17.4659
# 2020-07-14_09:04:47, Step 459/1062 in Ep 1, 1.28s  train_loss:17.5021
# 2020-07-14_09:05:13, Step 479/1062 in Ep 1, 1.29s  train_loss:17.3931
# 2020-07-14_09:05:38, Step 499/1062 in Ep 1, 1.28s  train_loss:17.4875
# 2020-07-14_09:06:04, Step 519/1062 in Ep 1, 1.28s  train_loss:19.9486
# 2020-07-14_09:06:30, Step 539/1062 in Ep 1, 1.28s  train_loss:18.3907
# 2020-07-14_09:06:56, Step 559/1062 in Ep 1, 1.28s  train_loss:16.0454
# Traceback (most recent call last):
#   File "train.py", line 152, in <module>
#     main(args)
#   File "train.py", line 90, in main
#     path=save_model_path)
#   File "train.py", line 109, in trainer
#     optimizer=optimizer,
#   File "/content/Strong_Baseline_of_Pedestrian_Attribute_Recognition/batch_engine.py", line 30, in batch_trainer
#     clip_grad_norm_(model.parameters(), max_norm=10.0)  # make larger learning rate works
#   File "/usr/local/lib/python3.6/dist-packages/torch/nn/utils/clip_grad.py", line 35, in clip_grad_norm_
#     if clip_coef < 1:
# KeyboardInterrupt

# %%
# !ls
# Out:
# baseline  dataset  README.md  script
